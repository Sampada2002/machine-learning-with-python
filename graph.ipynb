# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampada2002/machine-learning-with-python/blob/main/graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([1,2])
ypoints=np.array([2,5])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([50,100])
ypoints=np.array([40,200])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([20,100])
ypoints=np.array([50,500])
plt.plot(xpoints,ypoints,'*')
plt.show()

# %%
xpoints=np.array([1,6])
ypoints=np.array([2,10])
plt.plot(xpoints,ypoints,"*""k")
plt.show()

# %%
xpoints=np.array([1,6])
plt.plot(xpoints,"*")
plt.show()

# %%
xpoints=np.array([1,3,5,8])
ypoints=np.array([2,10,9,8])
plt.plot(xpoints,ypoints,"+""g")
plt.show()

# %%
xpoints=np.array([1,2,3,4])
ypoints=np.array([5,6,7,8])
plt.plot(xpoints,ypoints,marker="+",ms=24,color="b")
plt.show()

# %%
xpoints=np.array([2,10,20])
ypoints=np.array([5,50,200])
plt.plot(xpoints,ypoints,marker="o",ms=200,mec="k")
plt.plot(xpoints,ypoints,cycler=("color'=["cyan",\
                                "aqua",\
                                "teal",\
                                "greenyellow"])
plt.show()
# Out:
#   File "<ipython-input-19-005c39eff684>", line 4
#     plt.plot(xpoints,ypoints,cycler=("color'=["cyan",\
#                                                ^
# SyntaxError: invalid syntax

# %%
xpoints=np.array([1,2,3])
ypoints=np.array([100,200,300])
plt.plot(xpoints,ypoints,marker="o",ms=40,mfc="violet",mec="pink")
plt.show()

# %%
xpoints=([3,8,1,10])
plt.plot(xpoints,marker="o",ms=200,mfc="cyan",mec="cyan")
plt.show()

# %%
xpoints=np.array([1,2,3,4])
ypoints=np.array([20,30,10,500])
plt.plot(xpoints,ypoints,linestyle="dashed",marker="*",ms=90,mec="y",mfc="brown",linewidth=2)
plt.show()

# %%
plt.plot(xpoints,ypoints,linestyle="dotted",marker="+",ms=50,linewidth=2)
plt.show()

# %%
plt.plot(xpoints,ypoints,color="g",marker="*",ms=150,mec="b",mfc="teal",linestyle="dashed",linewidth="2")
plt.show()

# %%
y1=np.array([1,2,8,3])
y2=np.array([5,2,8,1,9])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1=np.array([1,2,8,3])
y2=np.array([5,2,8,9])
plt.plot(y1,y2)
plt.show()

# %%
y1=np.array([1,2,8,3])
y2=np.array([5,2,8,1,9])
plt.plot(y1,color="k")
plt.plot(y2)
plt.show()

# %%
y1=np.array([1,2,8,3])
y2=np.array([5,2,8,1,9])
plt.plot(y1,marker="*",color="k")
plt.plot(y2,marker="*",color="r")
plt.show()

# %%
x=np.array([70,40,20,90,10,50,60])
y=np.array([88,40,90,33,18,39,117])
plt.plot(x,y,color="violet",linewidth=1)
plt.xlabel("Year",color="red",fontsize=10,loc="left")
plt.ylabel("Food",color="red",fontsize=10,loc="top")
plt.title("Sample",color="red",fontsize=30)
# Out:
# Text(0.5, 1.0, 'Sample')

# %%
x=np.array([10,20,99,89])
y=np.array([12,34,56,23])
plt.title("sports")
plt.xlabel('Average')
plt.ylabel("calorie")
plt.plot(x,y,color="green")
plt.grid(color="cyan",linestyle="dashed")
plt.show()

# %%
x=np.array([10,20,99,89])
y=np.array([12,34,56,23])
plt.title("sports")
plt.xlabel('Average')
plt.ylabel("calorie")
plt.plot(x,y)
plt.grid(color="teal",axis='x')
plt.show()

# %%
x=np.array([10,20,99,89])
y=np.array([12,34,56,23])
plt.title("sports")
plt.xlabel('Average')
plt.ylabel("calorie")
plt.plot(x,y)
plt.grid(axis='y')
plt.show()

# %%
x=np.array([10,20,99,89,68])
y=np.array([12,34,56,23,55])
plt.title("sports")
plt.xlabel('Average')
plt.ylabel("calorie")
plt.plot(x,y)
plt.grid(color="peru",linestyle="--",linewidth=1.5)
plt.show()

# %%
x=np.array([10,20,99,89,68,78,44,31])
y=np.array([12,34,56,23,55,36,87,99])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("sports")
x=np.array([10,20,99,89,68])
y=np.array([12,34,56,23,55])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("sales")

plt.suptitle("my shop")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=np.array([10,20,99,89,68,78,44,31])
y=np.array([12,34,56,23,55,36,87,99])
plt.scatter(x,y)          #relatiosshio between to numerical attributes
plt.show()

# %%
x=np.array([10,20,99,89,68,78,44,31])
y=np.array([12,34,56,23,55,36,87,99])
plt.scatter(x,y)          


x=np.array([11,20,90,89,68,78,44,31,33])
y=np.array([12,39,56,20,50,36,7,39,44])
plt.scatter(x,y)  


plt.show()

# %%
x=np.array([10,20,99,89,68,78,44,31])
y=np.array([12,34,56,23,55,36,87,99])
plt.scatter(x,y,color="aqua")          


x=np.array([11,20,90,89,68,78,44,31,33])
y=np.array([12,39,56,20,50,36,7,39,44])
plt.scatter(x,y,color="blueviolet")  


plt.show()

# %%
 x=np.array(["s","W","R","P"])
 y=np.array([1,2,3,4])
 plt.bar(x,y,color="midnightblue",width=0.5)
 plt.show()

# %%
 x=np.array(["s","W","R","P"])
 y=np.array([1,2,3,4])
 plt.barh(x,y,color="olivedrab")
 plt.show()

# %%
 x=np.array(["s","W","R","P"])
 y=np.array([1,2,3,4])
 plt.barh(x,y,color="orangered",height=0.5)
 plt.show()

# %%
np.random.normal(15,5,1000)
# Out:
# array([14.31128947, 17.2147808 , 10.60933356, 18.21204194, 19.08093376,
#        20.36457251,  6.76947774, 16.54206026,  9.84864163, 23.24105645,
#        16.52643839, 21.60675005, 15.59657552,  8.06693361, 18.76126064,
#         8.7530668 , 14.7618509 , 18.95718747, 16.67872001, 21.74983389,
#        12.53926256, 20.27993964, 20.37729771, 21.58348561, 22.74972991,
#         4.06298893, 12.45031715, 17.3103223 , 11.36155467, -1.73869812,
#        18.16602615, 10.30969767, 12.71696946, 14.27685462, 15.25232866,
#        12.92939803,  3.91334318,  8.48542118,  7.69518138, 15.77623751,
#        15.14139703,  9.70262401, 14.75836558,  8.73220884, 18.69073455,
#        15.51240608, 18.69895705, 25.3456476 ,  1.02596462, 20.39556807,
#        24.78047943, 12.21576224, 14.16669916, 15.08931723, 18.85020812,
#        11.77588287,  2.55260741, 10.45621385, 12.35794012, 11.6965459 ,
#         9.54891542, 13.12585651, 10.8340554 , 17.45181496, 24.18241895,
# ...

# %%
plt.hist(x)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
y=np.array([2,3,5,6,10])
plt.pie(y)
plt.show()

# %%
y=np.array([2,3,5,6,10])
mylabels=["rutu","sakshi","anju","aryali","samp"]
plt.pie(y, labels=mylabels)
plt.show()

# %%
y=np.array([2,3,5,6,10])
mylabels=["rutu","sakshi","anju","aryali","samp"]
plt.pie(y, labels=mylabels, startangle=180)
plt.show()

# %%
y=np.array([2,3,5,6,10])
mylabels=["rutu","sakshi","anju","aryali","samp"]
myexplode=[0.2,0.5,0.8,0.3,0.4]
plt.pie(y, labels=mylabels,explode=myexplode)
plt.show()

# %%
y=np.array([2,3,5,6,10])
mylabels=["rutu","sakshi","anju","aryali","samp"]
mycolors=["cyan","red","blue","green","violet"]
plt.pie(y, labels=mylabels,colors=mycolors)
plt.show()

# %%
y=np.array([2,3,5,6,10])
mylabels=["rutu","sakshi","anju","aryali","samp"]
plt.pie(y)
plt.legend(labels=mylabels)
plt.show()
