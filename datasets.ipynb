# %% [markdown]
# <a href="https://colab.research.google.com/github/Sampada2002/machine-learning-with-python/blob/main/datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/Datasets/main/hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail(20)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119370  City Hotel            0        201               2017
# 119371  City Hotel            0        175               2017
# 119372  City Hotel            0        175               2017
# 119373  City Hotel            0        175               2017
# 119374  City Hotel            0        201               2017
# 119375  City Hotel            0        200               2017
# 119376  City Hotel            0        165               2017
# 119377  City Hotel            0        185               2017
# 119378  City Hotel            0        247               2017
# 119379  City Hotel            0        109               2017
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info
# Out:
# <bound method DataFrame.info of                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.sample()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2589  Resort Hotel            0          4               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2589            October                        43                         23
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2589                        0                     1       2  ...
#
#       deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 2589    No Deposit  240.0     NaN                    0     Transient  77.0
#
#       required_car_parking_spaces  total_of_special_requests  \
# 2589                            0                          1
#
#       reservation_status reservation_status_date
# 2589           Check-Out              10/24/2015
#
# [1 rows x 32 columns]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.describe(include="all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
import pandas as pd
import numpy as np

# %%
labels=['w','x','y','z']
a_list=[100,200,300,400]
array=np.array([1,2,3,4])
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(data=a_list)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
pd.Series(labels,array)
# Out:
# 1    w
# 2    x
# 3    y
# 4    z
# dtype: object

# %%
pd.Series(a_list,array)
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# dtype: int64

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports=pd.Series([1,2,3,4], index=['cricker','football','basketball','golf'])
sports
# Out:
# cricker       1
# football      2
# basketball    3
# golf          4
# dtype: int64

# %%
sports["golf"]
# Out:
# 4

# %%
sports1=pd.Series([11,2,9,4], index=['cricker','football','baseball','golf'])
sports1
# Out:
# cricker     11
# football     2
# baseball     9
# golf         4
# dtype: int64

# %%
sports+sports1
# Out:
# baseball       NaN
# basketball     NaN
# cricker       12.0
# football       4.0
# golf           8.0
# dtype: float64

# %%
df=pd.DataFrame(np.random.rand(8,5),index='A B C D E F G H'.split(),columns='score1 score2 score3 score4 score5'.split())
df
# Out:
#      score1    score2    score3    score4    score5
# A  0.359305  0.740307  0.212772  0.654553  0.392822
# B  0.823637  0.539613  0.676417  0.209372  0.306820
# C  0.333161  0.801256  0.176100  0.726529  0.394114
# D  0.053053  0.041209  0.521231  0.700216  0.039421
# E  0.180811  0.522565  0.674358  0.857052  0.098676
# F  0.944986  0.416756  0.735780  0.725210  0.778508
# G  0.072156  0.415296  0.339182  0.209128  0.043579
# H  0.536372  0.618219  0.463755  0.261568  0.256721

# %%
df["score3"]
# Out:
# A    0.212772
# B    0.676417
# C    0.176100
# D    0.521231
# E    0.674358
# F    0.735780
# G    0.339182
# H    0.463755
# Name: score3, dtype: float64

# %%
df[["score3","score2","score1"]]
# Out:
#      score3    score2    score1
# A  0.212772  0.740307  0.359305
# B  0.676417  0.539613  0.823637
# C  0.176100  0.801256  0.333161
# D  0.521231  0.041209  0.053053
# E  0.674358  0.522565  0.180811
# F  0.735780  0.416756  0.944986
# G  0.339182  0.415296  0.072156
# H  0.463755  0.618219  0.536372

# %%
df['score6']=df['score2']+df['score3']
df
# Out:
#      score1    score2    score3    score4    score5    score6
# A  0.359305  0.740307  0.212772  0.654553  0.392822  0.953080
# B  0.823637  0.539613  0.676417  0.209372  0.306820  1.216030
# C  0.333161  0.801256  0.176100  0.726529  0.394114  0.977356
# D  0.053053  0.041209  0.521231  0.700216  0.039421  0.562440
# E  0.180811  0.522565  0.674358  0.857052  0.098676  1.196922
# F  0.944986  0.416756  0.735780  0.725210  0.778508  1.152537
# G  0.072156  0.415296  0.339182  0.209128  0.043579  0.754477
# H  0.536372  0.618219  0.463755  0.261568  0.256721  1.081974

# %%
df2={'id':'101 102 103 104 154'.split(),'name':'s r p a c'.split(),'profit':'20 30 40 50 60'.split()}
df1=pd.DataFrame(df2)
df1
# Out:
#     id name profit
# 0  101    s     20
# 1  102    r     30
# 2  103    p     40
# 3  104    a     50
# 4  154    c     60

# %%
df1["name"]
# Out:
# 0    s
# 1    r
# 2    p
# 3    a
# 4    c
# Name: name, dtype: object

# %%
df1[['name','id']]
# Out:
#   name   id
# 0    s  101
# 1    r  102
# 2    p  103
# 3    a  104
# 4    c  154

# %%
df1=df1.drop('id',axis=1)
df1
# Out:
#   name profit
# 0    s     20
# 1    r     30
# 2    p     40
# 3    a     50
# 4    c     60

# %%
df1.drop(3)
# Out:
#   name profit
# 0    s     20
# 1    r     30
# 2    p     40
# 4    c     60
